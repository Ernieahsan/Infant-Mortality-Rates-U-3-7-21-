# %% [markdown]
# In this assignment you can identify a dataset of your interest and perform exploratory data analysis to better understand the data, investigate initial questions about it and develop preliminary insights and hypotheses. Your final submission will be a blog post consisting of a series of captioned visualizations that convey the key insights gained over the course of your analysis. You need to post the blog to medium or your github website.
#
# Documenting the data analysis process you went through is the main pedagogical goal of the assignment and more important than the design of the final visualization.
#
# We will go over the details of the project during class hours next week.

# %% [markdown]
# ##**Part 1: Select and Prepare the Data**

# %% [markdown]
# You should start by picking a topic area of interest to you and finding a dataset that can provide insights into that topic. We have provided some datasets below that you can start from. But we encourage you to investigate a different topic and dataset. If you self-select a dataset and are concerned about its appropriateness for the assignment, you can check with the TAs regarding the same.
#
# **Note:** The data collection and preparation (also known as data wrangling) can be a very tedious and time-consuming process. Be sure you have sufficient time to conduct exploratory analysis, after preparing the data.
#
# After selecting a topic and dataset – but prior to analysis – you should write down an initial set of at least three questions you’d like to investigate.

# %% [markdown]
# ## **Part 2: Exploratory Analysis**

# %% [markdown]
# Once you have picked the dataset and performed the initial data wrangling, you will perform exploratory analysis to investigate your data. For this assignment we would like you to use Pandas, NumPy and matplotlib to help you with the analysis.
#
# **Phase 1:** You should start the exploration by first examining the shape and structure of your data. What dimensions/variables does it contain and how are the data values distributed? Are there any notable data quality issues? Find out if there are missing values in the data and think of how you can handle them. Are there any surprising relationships between the dimensions/variables? Make sure to perform sanity checks for patterns you expect to see! Note that it may be the case that after doing a bit of exploration in phase 1 you find that your data is not as interesting as you first thought. In such cases you might consider returning to Part 1 and identifying a different dataset to work with. Such iteration on choosing the dataset is common, but also time-consuming, so make sure you leave time in your schedule for this.
#
# **Phase 2:** Next, you should investigate your initial questions, as well as any new questions that arise during your exploration. For each question, create a visualization that might provide a useful answer. Then refine the visualization (by adding additional variables, changing the sort ordering or axis scales, filtering or subsetting data, etc.) to develop better perspectives explore unexpected observations, or sanity check your assumptions. You should repeat this process for each of your questions, and also feel free to revise your questions or branch off to explore new questions as the data warrants.

# %% [markdown]
# ## **Final Deliverable**

# %% [markdown]
# Your final submission should consist of captioned visualizations detailing your most important insights. You will also work on writing and posting a blog to medium or your github website. Your “insights” can include important surprises or issues (such as data quality problems affecting your analysis) as well as responses to your analysis questions.
#
# Each visualization image should be a screenshot accompanied with a title and descriptive caption (1-4 sentences long) describing the insight(s) learned from that view. Provide sufficient detail for each caption such that anyone could read through your report and understand what you’ve learned. You are free, but not required, to annotate your images to draw attention to specific features of the data.
#
# Do not submit a blog cluttered with everything little thing you tried. Submit a clean report that highlights the most important “milestones” in your exploration, which can include initial overviews, identification of data quality problems, confirmations of key assumptions, and potential “discoveries”. Your blog should only present the final dataset you analyzed and should not describe any iterations on earlier datasets you might have initially explored.

# %% [markdown]
# ## **Data Sources**

# %% [markdown]
# There are a variety of data sources available online. Here are some possible sources to consider. If you have any questions about whether your dataset is appropriate, please talk to the TAs.
#
# **Data is Plural** - Variety of datasets and sources covering many topics.
#
# https://data.gov - U.S. Government open datasets.
#
# U.S. Census Bureau - Census data - https://data.census.gov/
#
# Federal Elections Commission - Campaign finance and expenditures. - https://www.fec.gov/data/
#
# Federal Aviation Administration - FAA data - https://www.faa.gov/data_research/
#
# https://www.kaggle.com/
#
# https://archive.ics.uci.edu/ml/index.php
#
# https://github.com/awesomedata/awesome-public-datasets - Awesome Public Datasets - Variety of public datasets.
#
# Stanford Cable TV News Analyzer - We have recently released a tool that can be used to analyze who and what appears in the last decade of Cable TV News (i.e. CNN, Fox News, MSNBC). The site lets you download data as well which you could use to conduct further analysis. - https://tvnews.stanford.edu/data

# %% [markdown]
# ### **Visualization Tool (matplotlib, seaborn, etc)**

# %% [markdown]
# One goal of this assignment is for you to learn to use and evaluate the effectiveness of these packages. In addition to these packages, you are free to also use other visualization tools as you see fit, for example, you could also take a look at Tableau.

# %% [markdown]
# ### **Data Wrangling Tools**

# %% [markdown]
# The data you choose may require reformatting, transformation or cleaning prior to visualization. You can use Pandas for data preparation.

# %% [markdown]
# ### **Grading**

# %% [markdown]
# Each submission will be graded based on both the analysis process and the included visualizations. Here are our grading criteria:
#
# **Appropriate Data Assessment (5):** Overview/understanding of the data is built from transformations and appropriate assessment of data quality. Poses clear questions.
#
# **Exploration Thoroughness (5):** Sufficient breadth of analysis, exploring questions in sufficient depth (with appropriate follow-up questions).
#
# **Documentation (Blog) (5):** Clear documentation of exploratory process, including clearly written, understandable captions that communicate primary insights.
#
# **Appropriate use of Numpy, Pandas, and Matplotlib (5)**  to ingest, clean, and present the data

# %% [markdown]
# ### **Submission Details**

# %% [markdown]
# This is an individual assignment. You may not work in groups. The assignment is due on Sunday (03/07/2021)
#
# To submit your assignment, download your notebook and zip all the necessary files(data files). Submit the zipped file to balckboard. Make sure the notebook and the zipped file is named in the format - EDA_LastName_FirstName. Be sure to include the link to access your blog in your notebook.
#
# Also include the link to your notebook in the submission.
#
# We will provide more details on the blog during the next week of class.
#
# **Note** - If the dataset is too large to be zipped and submitted on blackboard, only submit your notebook, add your dataset to your google drive and share a link to the file in your notebook.

# %%
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('infant_mortality_rate_per_1000_births.csv',header = 0, index_col = 0, parse_dates = [0])
print(data.head())
#print(data.info())
#data.loc[:,"1915":"2015"]
df = pd.DataFrame(data)
#column2015 = df['2015']
# Out:
#              1800  1801  1802  1803  1804  ...   2011   2012   2013  2014  2015
# country                                    ...
# Afghanistan   NaN   NaN   NaN   NaN   NaN  ...   73.4   71.7   69.9  68.1  66.3
# Albania       NaN   NaN   NaN   NaN   NaN  ...   14.3   13.8   13.3  12.9  12.5
# Algeria       NaN   NaN   NaN   NaN   NaN  ...   22.8   22.4   22.1  22.0  21.9
# Andorra       NaN   NaN   NaN   NaN   NaN  ...    2.4    2.3    2.2   2.1   2.1
# Angola        NaN   NaN   NaN   NaN   NaN  ...  107.0  104.0  101.0  98.8  96.0
#
# [5 rows x 216 columns]

# %%
#df2015 = pd.DataFrame(df['2015'])
df2015sorted = df.sort_values(by=['2015'],ascending = False)
df2015sorted5countries = df2015sorted[:5]
print(df2015sorted5countries)
# columnsfrom1965to2015 = df2015sorted['2000']
frame = pd.DataFrame(df2015sorted5countries,columns=["1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015"])
print(frame)
frameReversed = frame.transpose()

#year = ["2010","2011","2012","2013","2014","2015"]
plt.style.use('bmh')
frameReversed.plot()
plt.xlabel("Year")
plt.ylabel("Infant Deaths per 1000 births")
plt.title("Quarter Century Outlook: Top 5 Highest Rates")
plt.show()


#print(df.loc['Angola','2010':'2015'])
#df2015.sort
#max_2015_value = column2015.max()
#ind2015 = df['2015'].argmax()
#print(ind2015)
#dftop52015countries50years =df2015sorted5countries['2010':'2015']
#print(dftop52015countries50years)

#df10yearrange.plot()
#plt.show()
# Out:
#                           1800  1801  1802  1803  ...   2012   2013  2014  2015
# country                                           ...
# Angola                     NaN   NaN   NaN   NaN  ...  104.0  101.0  98.8  96.0
# Central African Republic   NaN   NaN   NaN   NaN  ...   97.7   96.1  93.5  91.5
# Sierra Leone               NaN   NaN   NaN   NaN  ...   97.9   93.8  90.2  87.1
# Chad                       NaN   NaN   NaN   NaN  ...   90.2   88.4  86.7  85.0
# Somalia                    NaN   NaN   NaN   NaN  ...   92.6   90.1  87.4  85.0
#
# [5 rows x 216 columns]
#                            1990   1991   1992   1993  ...   2012   2013  2014  2015
# country                                               ...
# Angola                    134.0  134.0  134.0  133.0  ...  104.0  101.0  98.8  96.0
# Central African Republic  115.0  115.0  115.0  115.0  ...   97.7   96.1  93.5  91.5
# Sierra Leone              157.0  156.0  156.0  155.0  ...   97.9   93.8  90.2  87.1
# Chad                      116.0  115.0  114.0  113.0  ...   90.2   88.4  86.7  85.0
# Somalia                   108.0  107.0  106.0  105.0  ...   92.6   90.1  87.4  85.0
#
# [5 rows x 26 columns]

# %%
data = pd.read_csv('infant_mortality_rate_per_1000_births.csv',header = 0, index_col = 0, parse_dates = [0])
df = pd.DataFrame(data)
#print(df.head())
dfReversed = df.transpose()
df1969 = dfReversed.iloc[169:]
print(df1969.head())
#print(dfReversed.head())
IndiaData = df.loc['India']
print(IndiaData)
# print(IndiaData.head())
# print(frameReversed.head())
plt.style.use('seaborn')
year = ["1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019"]

plt.bar(df1969.index, df1969.India,color = "b",label="India")
plt.bar(df1969.index,df1969.China,color="r",label="China")
plt.legend()
plt.xticks(rotation=90)
plt.xlabel("Year")
plt.ylabel("Infants Deaths per 1000 Births")
plt.title("India v. China: How 2 Powerful Countries Evolved")

plt.show()

# plt.bar(year,IndiaData.)
#plt.plot()
# Out:
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# country  Afghanistan  Albania  Algeria  ...  Yemen  Zambia  Zimbabwe
# 1969           210.0     80.2    148.0  ...  230.0   111.0      73.4
# 1970           206.0     76.8    146.0  ...  221.0   109.0      72.4
# 1971           202.0     74.1    144.0  ...  213.0   107.0      71.6
# 1972           198.0     71.0    141.0  ...  204.0   104.0      71.1
# 1973           194.0     68.3    137.0  ...  197.0   101.0      70.7
#
# [5 rows x 194 columns]
# 1800     NaN
# 1801     NaN
# 1802     NaN
# 1803     NaN
# 1804     NaN
#         ...
# 2011    44.4
# 2012    42.6
# 2013    40.9
# 2014    39.3
# 2015    37.9
# Name: India, Length: 216, dtype: float64

# %%
df2015sorted = df.sort_values(by=['2015'],ascending = True)
df2015sorted5countries = df2015sorted[:5]
print(df2015sorted5countries)
columnsfrom1965to2015 = df2015sorted['2000']
columns1950toNow = ["1950","1951","1952","1953","1954","1955","1956","1957","1958","1959","1960","1961","1962","1963","1964","1965","1966","1967","1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015"]
frame = pd.DataFrame(df2015sorted5countries,columns=columns1950toNow)
print(frame)
frameReversed = frame.transpose()


plt.style.use('bmh')
frameReversed.plot()
plt.xlabel("Year")
plt.ylabel("Infant Deaths per 1000 births")
plt.title("Post WWII Era: Comparison of Top 5 Lowest Rates")
plt.show()
# Out:
#             1800  1801  1802  1803  1804  ...  2011  2012  2013  2014  2015
# country                                   ...
# Luxembourg   NaN   NaN   NaN   NaN   NaN  ...   1.8   1.6   1.6   1.6   1.5
# Iceland      NaN   NaN   NaN   NaN   NaN  ...   1.8   1.7   1.6   1.6   1.6
# Finland      NaN   NaN   NaN   NaN   NaN  ...   2.4   2.2   2.1   2.0   1.9
# Japan        NaN   NaN   NaN   NaN   NaN  ...   2.3   2.2   2.1   2.1   2.0
# Norway       NaN   NaN   NaN   NaN   NaN  ...   2.5   2.3   2.3   2.2   2.0
#
# [5 rows x 216 columns]
#             1950  1951  1952  1953  1954  ...  2011  2012  2013  2014  2015
# country                                   ...
# Luxembourg   NaN   NaN   NaN   NaN   NaN  ...   1.8   1.6   1.6   1.6   1.5
# Iceland      NaN  24.0  22.9  21.8  20.8  ...   1.8   1.7   1.6   1.6   1.6
# Finland     44.0  34.2  33.0  31.7  30.4  ...   2.4   2.2   2.1   2.0   1.9
# Japan       57.8  53.6  49.9  46.6  43.7  ...   2.3   2.2   2.1   2.1   2.0
# Norway      26.9  25.2  23.7  22.5  21.7  ...   2.5   2.3   2.3   2.2   2.0
#
# [5 rows x 66 columns]

# %%
df1990 = dfReversed.iloc[190:]
dfaverage1990 = df1990.mean()
dfaverage1990SORTED = dfaverage1990.sort_values()
dfTop1990 = dfaverage1990SORTED[0:5]
dfBottom1990 = dfaverage1990SORTED[-5:]
print(dfTop1990)
print(dfBottom1990)
# plt.subplot(1,2,1)
plt.bar(dfTop1990.index,dfTop1990.values)
plt.xticks(rotation = 90)
plt.ylabel("Infant Deaths per 1000 Births")
plt.title("Top 5 Countries' Averages since 1990")
plt.show()


# plt.subplot(1,2,2)
plt.bar(dfBottom1990.index,dfBottom1990.values,color="r")
plt.xticks(rotation = 90)
plt.ylabel("Infant Deaths per 1000 Births")
plt.title("Bottom 5 Countries' Averages since 1990")


plt.show()
# print(dfaverage1990.head())
# Out:
# country
# Iceland      2.973077
# Japan        3.161538
# Singapore    3.161538
# Sweden       3.400000
# Finland      3.415385
# dtype: float64
# country
# Mozambique                  105.623077
# Central African Republic    108.596154
# Liberia                     109.523077
# Angola                      121.338462
# Sierra Leone                130.615385
# dtype: float64

# %%
#projecting Sierra Leone 
from fbprophet import Prophet
future = list()
dfReversed.reset_index(drop=False,inplace =True)
dfReversed['ds'] = dfReversed['index']
dfReversed['y'] = dfReversed["Sierra Leone"]
print(dfReversed.head())


# # print(dfReversed)

# dfSL.reset_index(drop=True,inplace =True)
# print(dfSL.head())
# # dfReversedSL = dfReversed.columns=['Sierra Leone','ds']
# # print(dfReversedSL)

# # dfReversed.index = dfReversed["ds"]
# # dfReversed.values=dfReversed["y"]

# model = Prophet()
# model.fit(dfSL)
# print(dfSL)
# Out:
# country index  Afghanistan  Albania  Algeria  ...  Zambia  Zimbabwe    ds   y
# 0        1800          NaN      NaN      NaN  ...     NaN       NaN  1800 NaN
# 1        1801          NaN      NaN      NaN  ...     NaN       NaN  1801 NaN
# 2        1802          NaN      NaN      NaN  ...     NaN       NaN  1802 NaN
# 3        1803          NaN      NaN      NaN  ...     NaN       NaN  1803 NaN
# 4        1804          NaN      NaN      NaN  ...     NaN       NaN  1804 NaN
#
# [5 rows x 197 columns]

# %%
dfSL = dfReversed[['ds','y']].copy()
dfSL.ds=pd.to_datetime(dfSL.ds)
print(dfSL.tail())
# Out:
# country         ds      y
# 211     2011-01-01  102.0
# 212     2012-01-01   97.9
# 213     2013-01-01   93.8
# 214     2014-01-01   90.2
# 215     2015-01-01   87.1

# %%
model = Prophet()
model.fit(dfSL)
print(dfSL.head())
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# country         ds   y
# 0       1800-01-01 NaN
# 1       1801-01-01 NaN
# 2       1802-01-01 NaN
# 3       1803-01-01 NaN
# 4       1804-01-01 NaN

# %%
future = ["2016", "2017", "2018", "2019", "2020","2021","2022","2023","2024","2025","2026","2027","2028","2029","2030"]
future=pd.DataFrame(future)
future.columns = ['ds']
future['ds'] = pd.to_datetime(future['ds'])
print(future)
# Out:
#            ds
# 0  2016-01-01
# 1  2017-01-01
# 2  2018-01-01
# 3  2019-01-01
# 4  2020-01-01
# 5  2021-01-01
# 6  2022-01-01
# 7  2023-01-01
# 8  2024-01-01
# 9  2025-01-01
# 10 2026-01-01
# 11 2027-01-01
# 12 2028-01-01
# 13 2029-01-01
# 14 2030-01-01

# %%
forecast = model.predict(future)
print(forecast[['ds','yhat']])
# Out:
#            ds       yhat
# 0  2016-01-01  82.494194
# 1  2017-01-01  79.356375
# 2  2018-01-01  74.839141
# 3  2019-01-01  70.505902
# 4  2020-01-01  66.360215
# 5  2021-01-01  63.222396
# 6  2022-01-01  58.705162
# 7  2023-01-01  54.371922
# 8  2024-01-01  50.226235
# 9  2025-01-01  47.088416
# 10 2026-01-01  42.571182
# 11 2027-01-01  38.237943
# 12 2028-01-01  34.092256
# 13 2029-01-01  30.954437
# 14 2030-01-01  26.437203

# %%
model.plot(forecast)
plt.title("Sierra Leone: The Decade Ahead")
plt.xlabel("Year")
plt.ylabel("Infant Deaths per 1000 births")
# plt.legend()
plt.show()

# %%
from fbprophet import Prophet
futureUS = list()
dfReversed.reset_index(drop=False,inplace =True)
dfReversed['ds'] = dfReversed['index']
dfReversed['y'] = dfReversed["United States"]
print(dfReversed.head())
# Out:
# country  level_0 index  Afghanistan  Albania  ...  Zambia  Zimbabwe    ds   y
# 0              0  1800          NaN      NaN  ...     NaN       NaN  1800 NaN
# 1              1  1801          NaN      NaN  ...     NaN       NaN  1801 NaN
# 2              2  1802          NaN      NaN  ...     NaN       NaN  1802 NaN
# 3              3  1803          NaN      NaN  ...     NaN       NaN  1803 NaN
# 4              4  1804          NaN      NaN  ...     NaN       NaN  1804 NaN
#
# [5 rows x 198 columns]

# %%
dfUS = dfReversed[['ds','y']].copy()
dfUS.ds=pd.to_datetime(dfUS.ds)
print(dfUS)
# Out:
# country         ds    y
# 0       1800-01-01  NaN
# 1       1801-01-01  NaN
# 2       1802-01-01  NaN
# 3       1803-01-01  NaN
# 4       1804-01-01  NaN
# ..             ...  ...
# 211     2011-01-01  6.1
# 212     2012-01-01  6.1
# 213     2013-01-01  5.9
# 214     2014-01-01  5.7
# 215     2015-01-01  5.6
#
# [216 rows x 2 columns]

# %%
modelUS = Prophet()
modelUS.fit(dfUS)
# print(dfUS.head())
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future = ["2016", "2017", "2018", "2019", "2020","2021","2022","2023","2024","2025","2026","2027","2028","2029","2030"]
future=pd.DataFrame(future)
future.columns = ['ds']
future['ds'] = pd.to_datetime(future['ds'])
print(future)
# Out:
#            ds
# 0  2016-01-01
# 1  2017-01-01
# 2  2018-01-01
# 3  2019-01-01
# 4  2020-01-01
# 5  2021-01-01
# 6  2022-01-01
# 7  2023-01-01
# 8  2024-01-01
# 9  2025-01-01
# 10 2026-01-01
# 11 2027-01-01
# 12 2028-01-01
# 13 2029-01-01
# 14 2030-01-01

# %%
forecastUS = modelUS.predict(future)
print(forecastUS[['ds','yhat']])
# Out:
#            ds      yhat
# 0  2016-01-01  5.298480
# 1  2017-01-01  5.245379
# 2  2018-01-01  5.148752
# 3  2019-01-01  5.004819
# 4  2020-01-01  4.814509
# 5  2021-01-01  4.761407
# 6  2022-01-01  4.664780
# 7  2023-01-01  4.520847
# 8  2024-01-01  4.330538
# 9  2025-01-01  4.277436
# 10 2026-01-01  4.180809
# 11 2027-01-01  4.036876
# 12 2028-01-01  3.846566
# 13 2029-01-01  3.793465
# 14 2030-01-01  3.696838

# %%
modelUS.plot(forecastUS)
plt.title("United States, Projected until 2030")
plt.xlabel("Year")
plt.ylabel("Infant Deaths per 1000 Births")
plt.show()
